# %%
# install dependencies
import pandas as pd
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv('HR_comma_sep (2).csv')

# %%
#exploring the data
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
data.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years    sales salary
# 14994                      0  support    low
# 14995                      0  support    low
# 14996                      0  support    low
# ...

# %%
data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
data.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# sales                    0
# salary                   0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
# sales                            0.003153         0.007772        0.009268
# salary                           0.011754         0.013965        0.009672
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
data['sales'] = encoder.fit_transform(data['sales'])
data['salary'] = encoder.fit_transform(data['salary'])

# %%
x = data.loc[:, ['satisfaction_level', 'last_evaluation', 'number_project','average_montly_hours']]

# %%
y = data.iloc[:, 0].values

# %%
x
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours
# 0                       157
# 1                       262
# 2                       272
# 3                       223
# 4                       159
# ...                     ...
# 14994                   151
# ...

# %%
y
# Out:
# array([0.38, 0.8 , 0.11, ..., 0.37, 0.11, 0.37])

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
x_scaled = sc.fit_transform(x)

# %%
x_scaled
# Out:
# array([[-0.93649469, -1.08727529, -1.46286291, -0.88203988],
#        [ 0.75281433,  0.84070693,  0.97111292,  1.22042276],
#        [-2.02247906,  0.95755433,  2.59376348,  1.4206573 ],
#        ...,
#        [-0.97671633, -1.08727529, -1.46286291, -1.16236823],
#        [-2.02247906,  1.42494396,  1.7824382 ,  1.58084493],
#        [-0.97671633, -1.14569899, -1.46286291, -0.86201642]])

# %%
from  sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 4)

# %%
p = pca.fit_transform(x_scaled)

# %%
p
# Out:
# array([[-1.93205404,  0.90134226,  0.06095048, -0.65435958],
#        [ 1.71291662, -0.76219664, -0.41242762,  0.14451983],
#        [ 3.01378468,  2.1074684 ,  0.2026485 ,  0.43338255],
#        ...,
#        [-2.09448712,  0.94040739,  0.25783068, -0.5380438 ],
#        [ 2.87709617,  1.77782775,  0.42970836, -0.41718136],
#        [-1.94986532,  0.95714494,  0.01628149, -0.65671525]])

# %%
principalDF = pd.DataFrame(data=p, columns = ['area1', 'area2','area3', 'area4'])
finalDF = pd.concat([principalDF, data[['salary']]], axis = 1)
finalDF.head()
# Out:
#       area1     area2     area3     area4  salary
# 0 -1.932054  0.901342  0.060950 -0.654360       1
# 1  1.712917 -0.762197 -0.412428  0.144520       2
# 2  3.013785  2.107468  0.202649  0.433383       2
# 3  1.303532 -0.479232  0.228267  0.386646       1
# 4 -1.938107  0.956999  0.002919 -0.665887       1
